# %%
from tms.tms import TMS
from tms.tester import Tester
from tms.scenario import Scenario
from tms.step import Step
from tms.bug import Bug

# %%
tms = TMS()
tms.add_tester('kirill', 1)
kirill = tms.get_tester('kirill')

# %%
kirill
# Out:
# {"name": "kirill", "level": 1, "current_scenario": "", "current_step": "", "current_step_number": 0}

# %%
tms
# Out:
# {"testers": [{"name": "kirill", "level": 1, "current_scenario": "", "current_step": "", "current_step_number": 0}], "scenarios": []}

# %%
x = 1
def func1(x, y):
    z = x + y
    return x + y

class MyClass:
    def __init__(self, x):
        self.x = x

    def my_method(self, y):
        self.x = self.x + y
