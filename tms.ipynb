# %%
from tms.db import SQLiteDB
from tms.models import Tester

# %%
with SQLiteDB("tms.db") as db:
    db.execute(Tester.create_table())

# %%
with SQLiteDB("tms.db") as db:
    print(db.execute(Tester.get_from_table('kirill')))
# Out:
# [(1, 'kirill', 1)]
