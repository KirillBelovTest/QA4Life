# %%
from tms.tms import TestManagmentSystem
tms = TestManagmentSystem()
tms.add_tester('kirill', 1)
kirill = tms.get_tester('kirill')

# %%
kirill.create_scenario('authorization')
kirill.take_scenario('authorization')
kirill.add_step('open login page', 'opened')
kirill.add_step('fill login field', 'filled')
kirill.add_step('fill password field', 'filled')
kirill.add_step('click submit button', 'success login')

# %%
tms
# Out:
# TestManagmentSystem(
#   testers: [
#     Tester(name = kirill, level = 1)
#   ],
#   scenarios: [
#     Scenario(name = authorization, steps = [
#         Step(name = open login page, expected_result = opened)
#         Step(name = fill login field, expected_result = filled)
#         Step(name = fill password field, expected_result = filled)
#         Step(name = click submit button, expected_result = success login)
#       ]
#     )
#   ]
# )

# %%
kirill.take_scenario('authorization')
kirill.take_next_step()
kirill.execute_step('opened')
# Out:
# False

# %%
kirill.current_step
# Out:
# Step(name = fill login field, expected_result = filled)

# %%
l = [1,2,3,4]

# %%
l.insert(0, 0)

# %%
l
# Out:
# [0, 1, 2, 3, 4]
